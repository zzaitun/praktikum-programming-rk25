# %% [markdown]
# # Ujian Tengah Semester Ganjil Robotika dan AI 2025
#
# Catatan:
#
# *Jawablah pertanyaan dengan baik dan dikumpulkan pada:*
# [KUMPUL UTS](https://forms.gle/bhScAfvDihZieBBP8)
#
# *Apabila secara keseluruhan hasil AI maka nilai akan dikurangi*

# %% [markdown]
# # Halaman Soal

# %% [markdown]
# 1. Apa yang anda ketahui tentang algoritma dan logika. Apa hubungannya? Buat satu contoh algoritma yang ada hubungannya tentang Komputer.

# %%
# Jawaban dalam bentuk comment python:
'''
Algoritma adalah urutan langkah-langkah logis dan sistematis yang digunakan untuk menyelesaikan suatu masalah atau mencapai tujuan tertentu. Setiap langkah dalam algoritma harus jelas, terstruktur, dan dapat dilaksanakan oleh komputer.

Logika adalah cara berpikir yang teratur dan rasional untuk menentukan keputusan yang benar berdasarkan kondisi atau aturan tertentu.

Algoritma Log-in pada aplikasi komputer:
	1.	Mulai.
	2.	Tampilkan form login.
	3.	Minta pengguna memasukkan username dan password.
	4.	Sistem membaca input dari pengguna.
	5.	Bandingkan username dan password dengan data yang tersimpan (misalnya di database).
	6.	Jika cocok, tampilkan pesan “Login berhasil” dan arahkan ke halaman utama.
	7.  Jika tidak cocok, tampilkan pesan “Username atau password salah”.
        - Meminta Kembali username dan password ketika salah dengan batas 3 kali.
        - Jika telah mencapai 3 kali, maka mengatur password ulang.
        - Setelah mengatur ulang password maka kembali ke langkah Nomor 2
	8.	Selesai.
'''

# %% [markdown]
# 2. Buatlah program Python yang meminta pengguna memasukkan nama dan umur, lalu menampilkan kalimat seperti contoh berikut:
#
# ```
# Masukkan nama Anda: Mahasiswa
# Masukkan NIM Anda: 6002201014
# Masukkan umur Anda: 21
#
# Halo Mahasiswa NIM 6002201014, umur Anda 21 tahun.
# ```

# %%
nama = input("Masukkan nama Anda: ")
nim = input("Masukkan NIM Anda: ")
usia = input("Masukkan umur Anda: ")


print(f"Halo {nama} NIM {nim}, umur Anda {usia} tahun.")

# %% [markdown]
# 3. Perhatikan potongan kode berikut:

# %%
a = input("Masukkan nilai= ")
b = 9
c = a + b
print(c)

# %% [markdown]
# a) Run kode di atas Jika inputan 6, Jelaskan yang terjadi setelah program dijalankan.
#
# b) Tuliskan versi kode yang benar agar menghasilkan output 15.

# %%
# Jawaban Bagian a). Jawab dalam bentuk comment python
'''
Program ini tidak tereksekusi sempurna atau terjadi error karena ada penggunaan operator numerik pada type data variabel yang berbeda (numerik dan string) sehingga tidak dapat dioperasikan.
'''

# %%
# Jawaban Bagian b).
""" Solusi agar Program berjalan baik adalah dengan melakukan casting variabel
"""
a = int(input("Masukkan nilai= "))
b = 9
c = a + b
print(c)
# Out:
# 15

# %% [markdown]
# 4. Soal dibawah dijawab sebagai comment di samping syntax

# %%
var = 6             # input dengan ujung nim anda baris ini

var  += 10             # arti syntax: Update variabel var dengan menambah 10 sehingga var=16
var  -= 4              # arti syntax: Update variabel var dengan mengurangi dengan 4 sehingga var=12
var //= 5              # arti syntax: Update variabel var metode floor dengan 5 sehingga var=2
var  %= 3              # arti syntax: Update variabel var metode modulus dengan 3 sehingga var=2
var **= 2              # arti syntax: Update variabel var metode kuadrat dengan 2 sehingga var=4         
var   = var < var**2   # arti syntax dan hasil outputnya: karena var^2 = 16 sehingga var < var**2 True dan Update variabel var menjadi True
print(var)
# Out:
# True

# %% [markdown]
# 5. Anda memiliki fungsi matematika: $f(x) = x^2-x+1 $. Buatkan program untuk mengetahui 4 nilai fungsi seperti berikut.
#
# Contoh output:
# ```
# pada x=1 nilai fungsi adalah: 1
# pada x=1.5 nilai fungsi adalah: 1.75
# pada x=2 nilai fungsi adalah: 3
# pada x=2.5 nilai fungsi adalah: 4.75
# ```

# %%
x1 = 1
fun1 = x1**2-x1+1
print(f'pada x={x1} nilai fungsi adalah: {fun1}')

x2 = 1.5
fun2 = x2**2-x1+1
print(f'pada x={x2} nilai fungsi adalah: {fun2}')

x3 = 2
fun3 = x3**2-x1+1
print(f'pada x={x3} nilai fungsi adalah: {fun3}')

x4 = 2.5
fun4 = x4**2-x1+1
print(f'pada x={x4} nilai fungsi adalah: {fun4}')
# Out:
# pada x=1 nilai fungsi adalah: 1
# pada x=1.5 nilai fungsi adalah: 2.25
# pada x=2 nilai fungsi adalah: 4
# pada x=2.5 nilai fungsi adalah: 6.25

# %% [markdown]
# 6. Tuliskan program Python yang meminta satu bilangan bulat, kemudian cek apakah bilangan ganjil? output harus seperti berikut:
#
# ```
# Masukkan Bilangan Genap: 5
# Pengecekan bilangan 5 merupakan ganjil adalah True
# ```

# %%
bilangan = int(input("Masukkan Bilangan Genap: "))
cek = bilangan%2 == 1

print(f"Pengecekan bilangan {bilangan} merupakan ganjil adalah {cek}")
# Out:
# Pengecekan bilangan 5 merupakan ganjil adalah True

# %% [markdown]
# 7. Buat program yang meminta inputan bilangan riil untuk rentang berikut. Apabila pada rentang yang benar maka mengembalikan True jika salah maka False.
#
# $x< -8$ atau $-4 < x < -2$ atau $0 < x < 3$
# ```
# contoh jika:
# Masukkan nilai pada rentang yang benar: 7
# Hasil Inputan: False
#
# contoh jika:
# Masukkan nilai pada rentang yang benar: 2
# Hasil Inputan: True
# ```

# %%
x = float(input("Masukkan nilai pada rentang x< -8 atau -4 < x < -2 atau 0 < x < 3: "))

cek1 = x<-8
cek2 = (x>-4 and x<-2) or (x>0 and x<3)

cek = cek1 or cek2

print(f"Hasil Inputan {x} adalah: {cek}")
# Out:
# Hasil Inputan 3.0 adalah: False

# %% [markdown]
# 8. Diberikan:
# ```
# teks = "   KuliAh&&-PemrOgrAman&&PythoN&&itu&&sEru^#dAN**menyEnangkaN!   "
# ```
# Tuliskan kode untuk:
#
# a) Menghapus spasi di awal dan akhir serta membuat kalimatnya menjadi benar
#
# b) Mengubah setiap huruf pertama pada kata menjadi huruf besar.
#
# c) Menghitung berapa kali huruf n muncul dalam string `teks`.

# %%
teks = "   KuliAh&&-PemrOgrAman&&PythoN&&itu&&sEru^#dAN**menyEnangkaN!   "

teks = teks.strip().replace("&&", " ").replace("-", " ").replace("^#", " ").replace("**", " ")

print(teks)
# Out:
# KuliAh  PemrOgrAman PythoN itu sEru dAN menyEnangkaN!

# %%
teks = teks.title()
print(teks)
# Out:
# Kuliah  Pemrograman Python Itu Seru Dan Menyenangkan!

# %%
muncul_n = teks.count('n')
print(f"Jumlah huruf 'n' muncul sebanyak {muncul_n} kali")
# Out:
# Jumlah huruf 'n' muncul sebanyak 7 kali

# %% [markdown]
# 9. Anda memiliki list:
# ```
# angka = [5, 10, 15, 20, 14, 2, 4, 12, 11, 9]
# ```
# Tuliskan kode untuk:
#
# a) Menambahkan elemen `25` ke akhir list dan di antara `10` dan `15`.
#
# b) Menghapus elemen `10`.
#
# c) Menampilkan elemen pertama dan terakhir.
#
# d) Hitung nilai rata-rata data `angka`

# %%
# Menambahkan elemen `25` ke akhir list dan di antara `10` dan `15`.
angka = [5, 10, 15, 20, 14, 2, 4, 12, 11, 9]

print(f"list lama: {angka}")

angka.append(25)
angka.insert(2, 25)

print(f"list baru: {angka}")
# Out:
# list lama: [5, 10, 15, 20, 14, 2, 4, 12, 11, 9]
# list baru: [5, 10, 25, 15, 20, 14, 2, 4, 12, 11, 9, 25]

# %%
# b) Menghapus elemen `10`.
print(f"list lama: {angka}")

angka.remove(10)

print(f"list baru: {angka}")
# Out:
# list lama: [5, 10, 25, 15, 20, 14, 2, 4, 12, 11, 9, 25]
# list baru: [5, 25, 15, 20, 14, 2, 4, 12, 11, 9, 25]

# %%
# c) Menampilkan elemen pertama dan terakhir.

print("Elemen pertama:", angka[0])
print("Elemen terakhir:", angka[-1])
# Out:
# Elemen pertama: 5
# Elemen terakhir: 25

# %%
# d) Hitung nilai rata-rata data `angka`

rata_rata = sum(angka) / len(angka)
print("Nilai rata-rata:", rata_rata)
# Out:
# Nilai rata-rata: 12.909090909090908

# %% [markdown]
# 10. Perhatikan dictionary berikut:
# ```
# data = {
#   "Bio" : {
#                 "nama"  : "Nama Lengkap",
#                 "NIM"   : 6002201014,
#                 "Prodi" : "Robotika dan AI",
#                 "tahun" : 2025
#             },
#   "Matakuliah" : {
#                 "mk"    : ['Kalkulus','PTI','PP','PKN','Agama','CINTA'],
#                 "nilai" : [91,89,90,90,91,94]
#             }
# }
# ```
# Buatkan program yang memberikan Ouput:
# ```
# Nama Mahasiswa  : Nama Lengkap
# Prodi           : Robotika dan AI - 2025
# NIM             : 6002201014
#
#
# Nilai Matakuliah Tertinggi adalah   : CINTA dengan nilai 94
# Nilai Matakuliah Terendah adalah    : PTI dengan nilai 89
#
# Nilai rata-rata matakuliah adalah: 90.83333333333333
#
# ```

# %%
data = {
  "Bio" : {
                "nama"  : "Mahasiswa",
                "nim"   : 6002201014,
                "prodi" : "Robotika dan AI",
                "tahun" : 2025
            },
  "Matakuliah" : {
                "mk"    : ['Kalkulus','PTI','PP','PKN','Agama','CINTA'],
                "nilai" : [91,89,90,90,91,94]
            }
}

# %%
print(f"Nama Mahasiswa  : {data['Bio']['nama']}")
print(f"Prodi           : {data['Bio']['prodi']} - {data['Bio']['tahun']}")
print(f"NIM             : {data['Bio']['nim']}")

maxi = max(data["Matakuliah"]["nilai"])
ind  = data["Matakuliah"]["nilai"].index(maxi)
mkul = data["Matakuliah"]["mk"][ind]

mini  = min(data["Matakuliah"]["nilai"])
ind2  = data["Matakuliah"]["nilai"].index(mini)
mkul2 = data["Matakuliah"]["mk"][ind2]

print(f'Nilai Matakuliah Tertinggi adalah   : {mkul} dengan nilai {maxi}')
print(f'Nilai Matakuliah Terendah adalah    : {mkul2} dengan nilai {mini}')

print(f'Nilai rata-rata matakuliah adalah: {sum(data["Matakuliah"]["nilai"])/len(data["Matakuliah"]["nilai"])}')
# Out:
# Nama Mahasiswa  : Mahasiswa
# Prodi           : Robotika dan AI - 2025
# NIM             : 6002201014
# Nilai Matakuliah Tertinggi adalah   : CINTA dengan nilai 94
# Nilai Matakuliah Terendah adalah    : PTI dengan nilai 89
# Nilai rata-rata matakuliah adalah: 90.83333333333333
